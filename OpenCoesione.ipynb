# %%
import pandas as pd
project_20 = pd.read_csv("dati/progetti_esteso_CULTURA_TURISMO_2014-2020_20250430.csv", sep=';', low_memory=False)
project_20.head()
# Out:
#    COD_LOCALE_PROGETTO              CUP  \
# 0  6IGRUEE497_98540_13  D36J20001910005
# 1     6IGRUEF426_12855  D42H23000340001
# 2     6IGRUEF877_22485  B69J20002290001
# 3     6IGRUEF934_15284  G57H20001950001
# 4     6IGRUEF934_15853  G57H21001140001
#
#                                   OC_TITOLO_PROGETTO  \
# 0  MANUTENZIONE STRAORDINARIA CON SOSTITUZIONE IN...
# 1  LAVORI DI ADEGUAMENTO/RISTRUTTURAZIONE DI LOCA...
# 2  GRACIELA ANA DESIMONI*AVVISO PUBBLICO PER LA C...
# 3  Realizzazione locale ristorazione nell'edifici...
# 4  REALIZZAZIONE LOCALE RISTORAZIONE NELL'EDIFICI...
#
#                                  OC_SINTESI_PROGETTO  \
# 0  Manutenzione straordinaria per efficientamento...
# 1  LAVORI DI ADEGUAMENTO/RISTRUTTURAZIONE DI LOCA...
# 2  GRACIELA ANA DESIMONI*AVVISO PUBBLICO PER LA C...
# 3  Realizzazione locale ristorazione nell'edifici...
# 4  REALIZZAZIONE LOCALE RISTORAZIONE NELL'EDIFICI...
#
#                                              OC_LINK  OC_COD_CICLO  \
# 0  https://opencoesione.gov.it/it/dati/progetti/6...             2
# 1  https://opencoesione.gov.it/it/dati/progetti/6...             2
# 2  https://opencoesione.gov.it/it/dati/progetti/6...             2
# 3  https://opencoesione.gov.it/it/dati/progetti/6...             2
# 4  https://opencoesione.gov.it/it/dati/progetti/6...             2
#
#                       OC_DESCR_CICLO  OC_COD_TEMA_SINTETICO  \
# 0  Ciclo di programmazione 2014-2020                      6
# 1  Ciclo di programmazione 2014-2020                      6
# 2  Ciclo di programmazione 2014-2020                      6
# 3  Ciclo di programmazione 2014-2020                      6
# 4  Ciclo di programmazione 2014-2020                      6
#
#    OC_TEMA_SINTETICO COD_GRANDE_PROGETTO  ... COD_INDICATORE_3  \
# 0  Cultura e turismo                 NaN  ...              NaN
# 1  Cultura e turismo                 NaN  ...              NaN
# 2  Cultura e turismo                 NaN  ...              NaN
# 3  Cultura e turismo                 NaN  ...              NaN
# 4  Cultura e turismo                 NaN  ...              NaN
#
#    DESCR_INDICATORE_3 UNITA_MISURA_INDICATORE_3  PROGRAMMATO_INDICATORE_3  \
# 0                 NaN                       NaN                       NaN
# 1                 NaN                       NaN                       NaN
# 2                 NaN                       NaN                       NaN
# 3                 NaN                       NaN                       NaN
# 4                 NaN                       NaN                       NaN
#
#   REALIZZATO_INDICATORE_3  COD_INDICATORE_4 DESCR_INDICATORE_4  \
# 0                     NaN               NaN                NaN
# 1                     NaN               NaN                NaN
# 2                     NaN               NaN                NaN
# 3                     NaN               NaN                NaN
# 4                     NaN               NaN                NaN
#
#    UNITA_MISURA_INDICATORE_4 PROGRAMMATO_INDICATORE_4  REALIZZATO_INDICATORE_4
# 0                        NaN                      NaN                      NaN
# 1                        NaN                      NaN                      NaN
# 2                        NaN                      NaN                      NaN
# 3                        NaN                      NaN                      NaN
# 4                        NaN                      NaN                      NaN
#
# [5 rows x 200 columns]

# %%
project_20 = project_20[['CUP','DATA_INIZIO_PREV_STUDIO_FATT','OC_DATA_INIZIO_PROGETTO','OC_DATA_FINE_PROGETTO_EFFETTIVA','DEN_REGIONE','DEN_PROVINCIA','DEN_COMUNE','FINANZ_TOTALE_PUBBLICO','FINANZ_STATO_ESTERO','FINANZ_PRIVATO']]
project_20
# Out:
#                    CUP  DATA_INIZIO_PREV_STUDIO_FATT  OC_DATA_INIZIO_PROGETTO  \
# 0      D36J20001910005                           NaN                 20201113
# 1      D42H23000340001                           NaN                 20240418
# 2      B69J20002290001                           NaN                 20201229
# 3      G57H20001950001                           NaN                 20210210
# 4      G57H21001140001                           NaN                 20210430
# ...                ...                           ...                      ...
# 14737  I84E21024540005                           NaN                 20210227
# 14738  F24E21001130001                           NaN                 20210927
# 14739  H81G22000290005                           NaN                 20230704
# 14740  B48E22000100001                           NaN                 20220620
# 14741  B87D22000350005                           NaN                 20221010
#
#        OC_DATA_FINE_PROGETTO_EFFETTIVA DEN_REGIONE  DEN_PROVINCIA  \
# 0                           20211108.0   LOMBARDIA        BRESCIA
# 1                           20240628.0    CAMPANIA        SALERNO
# 2                           20211019.0   LOMBARDIA           COMO
# 3                           20210711.0    SARDEGNA       ORISTANO
# 4                           20211001.0    SARDEGNA       ORISTANO
# ...                                ...         ...            ...
# 14737                              NaN     ABRUZZO         CHIETI
# 14738                       20211011.0     ABRUZZO       L'AQUILA
# 14739                              NaN      MARCHE  ASCOLI PICENO
# 14740                       20220927.0      MOLISE        ISERNIA
# 14741                       20221022.0   LOMBARDIA        BRESCIA
#
#             DEN_COMUNE FINANZ_TOTALE_PUBBLICO FINANZ_STATO_ESTERO  \
# 0             Lavenone               21329,99                0,00
# 1      Montano Antilia               53876,46                0,00
# 2                Nesso                 639,87                0,00
# 3             Norbello               17540,00                0,00
# 4             Norbello               17540,00                0,00
# ...                ...                    ...                 ...
# 14737  Civitaluparella                 500,00                0,00
# 14738         Corfinio                1500,00                0,00
# 14739            Force                2473,91                0,00
# 14740        Frosolone               49956,43                0,00
# 14741         Incudine                5999,86                0,00
#
#       FINANZ_PRIVATO
# 0               0,00
# 1               0,00
# 2               0,00
# 3               0,00
# 4               0,00
# ...              ...
# 14737           0,00
# 14738           0,00
# 14739           0,00
# 14740           0,00
# 14741           0,00
#
# [14742 rows x 10 columns]

# %%
project_27 = pd.read_csv("dati/progetti_esteso_CULTURA_TURISMO_2021-2027_20250430.csv", sep=';', low_memory=False)
project_27.head()
# Out:
#   COD_LOCALE_PROGETTO              CUP  \
# 0        6TO1121730/1  H37H21001230002
# 1        6TO1121730/2  H15F21000290002
# 2        6TO1189319/2  H78C18000080004
# 3        6TO1189319/3  C57H21000820005
# 4        6TO1189319/4  C52E18000090004
#
#                                   OC_TITOLO_PROGETTO  \
# 0  1121730/1-Finanziamento progetti a valere su F...
# 1  1121730/2-Finanziamento progetti a valere su F...
# 2  1189319/2-Nuovo Polo Culturale edificio storic...
# 3                                         1189319/3-
# 4  1189319/4-Teatro Manzoni ¿ Interventi di adegu...
#
#                                  OC_SINTESI_PROGETTO  \
# 0  FSC 2021/2027 - Impegno di spesa nei confronti...
# 1  FSC 2021/2027 - Impegno di spesa nei confronti...
# 2  Interventi finanziati a valere sull'anticipazi...
# 3  Interventi finanziati a valere sull'anticipazi...
# 4  Interventi finanziati a valere sull'anticipazi...
#
#                                              OC_LINK  OC_COD_CICLO  \
# 0  https://opencoesione.gov.it/it/dati/progetti/6...             3
# 1  https://opencoesione.gov.it/it/dati/progetti/6...             3
# 2  https://opencoesione.gov.it/it/dati/progetti/6...             3
# 3  https://opencoesione.gov.it/it/dati/progetti/6...             3
# 4  https://opencoesione.gov.it/it/dati/progetti/6...             3
#
#                       OC_DESCR_CICLO  OC_COD_TEMA_SINTETICO  \
# 0  Ciclo di programmazione 2021-2027                      6
# 1  Ciclo di programmazione 2021-2027                      6
# 2  Ciclo di programmazione 2021-2027                      6
# 3  Ciclo di programmazione 2021-2027                      6
# 4  Ciclo di programmazione 2021-2027                      6
#
#    OC_TEMA_SINTETICO  COD_GRANDE_PROGETTO  ...  COD_INDICATORE_3  \
# 0  Cultura e turismo                  NaN  ...               NaN
# 1  Cultura e turismo                  NaN  ...               NaN
# 2  Cultura e turismo                  NaN  ...               NaN
# 3  Cultura e turismo                  NaN  ...               NaN
# 4  Cultura e turismo                  NaN  ...               NaN
#
#    DESCR_INDICATORE_3 UNITA_MISURA_INDICATORE_3  PROGRAMMATO_INDICATORE_3  \
# 0                 NaN                       NaN                       NaN
# 1                 NaN                       NaN                       NaN
# 2                 NaN                       NaN                       NaN
# 3                 NaN                       NaN                       NaN
# 4                 NaN                       NaN                       NaN
#
#   REALIZZATO_INDICATORE_3  COD_INDICATORE_4 DESCR_INDICATORE_4  \
# 0                     NaN               NaN                NaN
# 1                     NaN               NaN                NaN
# 2                     NaN               NaN                NaN
# 3                     NaN               NaN                NaN
# 4                     NaN               NaN                NaN
#
#    UNITA_MISURA_INDICATORE_4 PROGRAMMATO_INDICATORE_4  REALIZZATO_INDICATORE_4
# 0                        NaN                      NaN                      NaN
# 1                        NaN                      NaN                      NaN
# 2                        NaN                      NaN                      NaN
# 3                        NaN                      NaN                      NaN
# 4                        NaN                      NaN                      NaN
#
# [5 rows x 200 columns]

# %%
project_27 = project_27[['CUP', 'DATA_INIZIO_PREV_STUDIO_FATT','OC_DATA_INIZIO_PROGETTO','OC_DATA_FINE_PROGETTO_EFFETTIVA','DEN_REGIONE','DEN_PROVINCIA','DEN_COMUNE','FINANZ_TOTALE_PUBBLICO','FINANZ_STATO_ESTERO','FINANZ_PRIVATO']]
project_27
# Out:
#                  CUP  DATA_INIZIO_PREV_STUDIO_FATT  OC_DATA_INIZIO_PROGETTO  \
# 0    H37H21001230002                    20221020.0               20220227.0
# 1    H15F21000290002                    20211215.0               20211215.0
# 2    H78C18000080004                    20230213.0               20230213.0
# 3    C57H21000820005                    20090115.0               20090115.0
# 4    C52E18000090004                    20170804.0               20170804.0
# ..               ...                           ...                      ...
# 867  F25F21001690006                    20231129.0               20211222.0
# 868  I83B19000340006                    20190227.0               20241205.0
# 869  G41E19000000004                    20190225.0               20181207.0
# 870  G43D19000040006                    20190411.0               20190917.0
# 871  G49G20000140006                    20200713.0               20201127.0
#
#      OC_DATA_FINE_PROGETTO_EFFETTIVA DEN_REGIONE DEN_PROVINCIA  \
# 0                                NaN     TOSCANA       FIRENZE
# 1                         20230623.0     TOSCANA       FIRENZE
# 2                                NaN     TOSCANA       LIVORNO
# 3                                NaN     TOSCANA       PISTOIA
# 4                         20211206.0     TOSCANA       PISTOIA
# ..                               ...         ...           ...
# 867                              NaN     SICILIA        RAGUSA
# 868                              NaN     SICILIA       PALERMO
# 869                              NaN     LIGURIA     LA SPEZIA
# 870                       20230530.0     LIGURIA     LA SPEZIA
# 871                       20230530.0     LIGURIA     LA SPEZIA
#
#          DEN_COMUNE FINANZ_TOTALE_PUBBLICO FINANZ_STATO_ESTERO FINANZ_PRIVATO
# 0    Bagno a Ripoli              340000,00                0,00           0,00
# 1           Firenze              150000,00                0,00           0,00
# 2          Piombino             3433865,20                0,00           0,00
# 3           Pistoia             1500000,00                0,00           0,00
# 4           Pistoia              300000,00                0,00           0,00
# ..              ...                    ...                 ...            ...
# 867          Ragusa             2000000,00                0,00           0,00
# 868           Gangi              412543,00                0,00           0,00
# 869       La Spezia              900000,00                0,00           0,00
# 870       La Spezia             1500000,00                0,00           0,00
# 871       La Spezia              726000,00                0,00           0,00
#
# [872 rows x 10 columns]

# %%
all_projects = pd.concat([project_20, project_27], ignore_index=True)
all_projects
# Out:
#                    CUP  DATA_INIZIO_PREV_STUDIO_FATT  OC_DATA_INIZIO_PROGETTO  \
# 0      D36J20001910005                           NaN               20201113.0
# 1      D42H23000340001                           NaN               20240418.0
# 2      B69J20002290001                           NaN               20201229.0
# 3      G57H20001950001                           NaN               20210210.0
# 4      G57H21001140001                           NaN               20210430.0
# ...                ...                           ...                      ...
# 15609  F25F21001690006                    20231129.0               20211222.0
# 15610  I83B19000340006                    20190227.0               20241205.0
# 15611  G41E19000000004                    20190225.0               20181207.0
# 15612  G43D19000040006                    20190411.0               20190917.0
# 15613  G49G20000140006                    20200713.0               20201127.0
#
#        OC_DATA_FINE_PROGETTO_EFFETTIVA DEN_REGIONE DEN_PROVINCIA  \
# 0                           20211108.0   LOMBARDIA       BRESCIA
# 1                           20240628.0    CAMPANIA       SALERNO
# 2                           20211019.0   LOMBARDIA          COMO
# 3                           20210711.0    SARDEGNA      ORISTANO
# 4                           20211001.0    SARDEGNA      ORISTANO
# ...                                ...         ...           ...
# 15609                              NaN     SICILIA        RAGUSA
# 15610                              NaN     SICILIA       PALERMO
# 15611                              NaN     LIGURIA     LA SPEZIA
# 15612                       20230530.0     LIGURIA     LA SPEZIA
# 15613                       20230530.0     LIGURIA     LA SPEZIA
#
#             DEN_COMUNE FINANZ_TOTALE_PUBBLICO FINANZ_STATO_ESTERO  \
# 0             Lavenone               21329,99                0,00
# 1      Montano Antilia               53876,46                0,00
# 2                Nesso                 639,87                0,00
# 3             Norbello               17540,00                0,00
# 4             Norbello               17540,00                0,00
# ...                ...                    ...                 ...
# 15609           Ragusa             2000000,00                0,00
# 15610            Gangi              412543,00                0,00
# 15611        La Spezia              900000,00                0,00
# 15612        La Spezia             1500000,00                0,00
# 15613        La Spezia              726000,00                0,00
#
#       FINANZ_PRIVATO
# 0               0,00
# 1               0,00
# 2               0,00
# 3               0,00
# 4               0,00
# ...              ...
# 15609           0,00
# 15610           0,00
# 15611           0,00
# 15612           0,00
# 15613           0,00
#
# [15614 rows x 10 columns]

# %%
all_projects = all_projects.drop_duplicates(subset=['CUP'], keep='first')
all_projects
# Out:
#                    CUP  DATA_INIZIO_PREV_STUDIO_FATT  OC_DATA_INIZIO_PROGETTO  \
# 0      D36J20001910005                           NaN               20201113.0
# 1      D42H23000340001                           NaN               20240418.0
# 2      B69J20002290001                           NaN               20201229.0
# 3      G57H20001950001                           NaN               20210210.0
# 4      G57H21001140001                           NaN               20210430.0
# ...                ...                           ...                      ...
# 15609  F25F21001690006                    20231129.0               20211222.0
# 15610  I83B19000340006                    20190227.0               20241205.0
# 15611  G41E19000000004                    20190225.0               20181207.0
# 15612  G43D19000040006                    20190411.0               20190917.0
# 15613  G49G20000140006                    20200713.0               20201127.0
#
#        OC_DATA_FINE_PROGETTO_EFFETTIVA DEN_REGIONE DEN_PROVINCIA  \
# 0                           20211108.0   LOMBARDIA       BRESCIA
# 1                           20240628.0    CAMPANIA       SALERNO
# 2                           20211019.0   LOMBARDIA          COMO
# 3                           20210711.0    SARDEGNA      ORISTANO
# 4                           20211001.0    SARDEGNA      ORISTANO
# ...                                ...         ...           ...
# 15609                              NaN     SICILIA        RAGUSA
# 15610                              NaN     SICILIA       PALERMO
# 15611                              NaN     LIGURIA     LA SPEZIA
# 15612                       20230530.0     LIGURIA     LA SPEZIA
# 15613                       20230530.0     LIGURIA     LA SPEZIA
#
#             DEN_COMUNE FINANZ_TOTALE_PUBBLICO FINANZ_STATO_ESTERO  \
# 0             Lavenone               21329,99                0,00
# 1      Montano Antilia               53876,46                0,00
# 2                Nesso                 639,87                0,00
# 3             Norbello               17540,00                0,00
# 4             Norbello               17540,00                0,00
# ...                ...                    ...                 ...
# 15609           Ragusa             2000000,00                0,00
# 15610            Gangi              412543,00                0,00
# 15611        La Spezia              900000,00                0,00
# 15612        La Spezia             1500000,00                0,00
# 15613        La Spezia              726000,00                0,00
#
#       FINANZ_PRIVATO
# 0               0,00
# 1               0,00
# 2               0,00
# 3               0,00
# 4               0,00
# ...              ...
# 15609           0,00
# 15610           0,00
# 15611           0,00
# 15612           0,00
# 15613           0,00
#
# [14740 rows x 10 columns]

# %%
all_project = all_projects
date_columns = ['DATA_INIZIO_PREV_STUDIO_FATT','OC_DATA_INIZIO_PROGETTO','OC_DATA_FINE_PROGETTO_EFFETTIVA']
for col in date_columns:
    all_project[col] = pd.to_datetime(all_project[col], yearfirst=True, errors='coerce')
all_project
# Out:
# C:\Users\annan\AppData\Local\Temp\ipykernel_19332\2815759317.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_project[col] = pd.to_datetime(all_project[col], yearfirst=True, errors='coerce')
# C:\Users\annan\AppData\Local\Temp\ipykernel_19332\2815759317.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_project[col] = pd.to_datetime(all_project[col], yearfirst=True, errors='coerce')
# C:\Users\annan\AppData\Local\Temp\ipykernel_19332\2815759317.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_project[col] = pd.to_datetime(all_project[col], yearfirst=True, errors='coerce')
#                    CUP  DATA_INIZIO_PREV_STUDIO_FATT  \
# 0      D36J20001910005                           NaT
# 1      D42H23000340001                           NaT
# 2      B69J20002290001                           NaT
# 3      G57H20001950001                           NaT
# 4      G57H21001140001                           NaT
# ...                ...                           ...
# 15609  F25F21001690006 1970-01-01 00:00:00.020231129
# 15610  I83B19000340006 1970-01-01 00:00:00.020190227
# 15611  G41E19000000004 1970-01-01 00:00:00.020190225
# 15612  G43D19000040006 1970-01-01 00:00:00.020190411
# 15613  G49G20000140006 1970-01-01 00:00:00.020200713
#
#             OC_DATA_INIZIO_PROGETTO OC_DATA_FINE_PROGETTO_EFFETTIVA  \
# 0     1970-01-01 00:00:00.020201113   1970-01-01 00:00:00.020211108
# 1     1970-01-01 00:00:00.020240418   1970-01-01 00:00:00.020240628
# 2     1970-01-01 00:00:00.020201229   1970-01-01 00:00:00.020211019
# 3     1970-01-01 00:00:00.020210210   1970-01-01 00:00:00.020210711
# 4     1970-01-01 00:00:00.020210430   1970-01-01 00:00:00.020211001
# ...                             ...                             ...
# 15609 1970-01-01 00:00:00.020211222                             NaT
# 15610 1970-01-01 00:00:00.020241205                             NaT
# 15611 1970-01-01 00:00:00.020181207                             NaT
# 15612 1970-01-01 00:00:00.020190917   1970-01-01 00:00:00.020230530
# 15613 1970-01-01 00:00:00.020201127   1970-01-01 00:00:00.020230530
#
#       DEN_REGIONE DEN_PROVINCIA       DEN_COMUNE FINANZ_TOTALE_PUBBLICO  \
# 0       LOMBARDIA       BRESCIA         Lavenone               21329,99
# 1        CAMPANIA       SALERNO  Montano Antilia               53876,46
# 2       LOMBARDIA          COMO            Nesso                 639,87
# 3        SARDEGNA      ORISTANO         Norbello               17540,00
# 4        SARDEGNA      ORISTANO         Norbello               17540,00
# ...           ...           ...              ...                    ...
# 15609     SICILIA        RAGUSA           Ragusa             2000000,00
# 15610     SICILIA       PALERMO            Gangi              412543,00
# 15611     LIGURIA     LA SPEZIA        La Spezia              900000,00
# 15612     LIGURIA     LA SPEZIA        La Spezia             1500000,00
# 15613     LIGURIA     LA SPEZIA        La Spezia              726000,00
#
#       FINANZ_STATO_ESTERO FINANZ_PRIVATO
# 0                    0,00           0,00
# 1                    0,00           0,00
# 2                    0,00           0,00
# 3                    0,00           0,00
# 4                    0,00           0,00
# ...                   ...            ...
# 15609                0,00           0,00
# 15610                0,00           0,00
# 15611                0,00           0,00
# 15612                0,00           0,00
# 15613                0,00           0,00
#
# [14740 rows x 10 columns]

# %%
TO DO

- convert date
- order by year
- extract trend for n. of projects and funding per year
# Out:
#   Cell In[11], line 1
#     TO DO
#        ^
# SyntaxError: invalid syntax
