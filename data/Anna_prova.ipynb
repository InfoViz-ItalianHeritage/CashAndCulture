# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/annan/Downloads/efficienza_tpl_filtered.csv")
df = df.reset_index(drop=False)
df
# Out:
#      level_0   level_1              level_2                   level_3 level_4  \
# 0    Annuale  Piemonte  Qualità dei servizi  Posti-km offerti dal Tpl  Totale
# 1    Annuale  Piemonte  Qualità dei servizi  Posti-km offerti dal Tpl  Totale
# 2    Annuale  Piemonte  Qualità dei servizi  Posti-km offerti dal Tpl  Totale
# 3    Annuale  Piemonte  Qualità dei servizi  Posti-km offerti dal Tpl  Totale
# 4    Annuale  Piemonte  Qualità dei servizi  Posti-km offerti dal Tpl  Totale
# ..       ...       ...                  ...                       ...     ...
# 195  Annuale  Sardegna  Qualità dei servizi  Posti-km offerti dal Tpl  Totale
# 196  Annuale  Sardegna  Qualità dei servizi  Posti-km offerti dal Tpl  Totale
# 197  Annuale  Sardegna  Qualità dei servizi  Posti-km offerti dal Tpl  Totale
# 198  Annuale  Sardegna  Qualità dei servizi  Posti-km offerti dal Tpl  Totale
# 199  Annuale  Sardegna  Qualità dei servizi  Posti-km offerti dal Tpl  Totale
#
# ...

# %%
df = df.loc[:,["level_1", "Frequenza", "Territorio"]]
df.columns = ["Territorio", "Anno", "Osservazioni"]
df
# Out:
#     Territorio  Anno  Osservazioni
# 0     Piemonte  2014          4537
# 1     Piemonte  2015          5084
# 2     Piemonte  2016          5042
# 3     Piemonte  2017          5197
# 4     Piemonte  2018          5026
# ..         ...   ...           ...
# 195   Sardegna  2019          3411
# 196   Sardegna  2020          2424
# 197   Sardegna  2021          3488
# 198   Sardegna  2022          3726
# 199   Sardegna  2023          3406
#
# [200 rows x 3 columns]

# %%
df2 = pd.read_csv("C:/Users/annan/Downloads/indice_cultura.csv")
df2
# Out:
#                                          Frequenza  \
# Annuale Piemonte  Paesaggio e patrimonio culturale
#         Piemonte  Paesaggio e patrimonio culturale
#         Piemonte  Paesaggio e patrimonio culturale
#         Piemonte  Paesaggio e patrimonio culturale
#         Piemonte  Paesaggio e patrimonio culturale
# ...                                            ...
#         Sardegna  Paesaggio e patrimonio culturale
#         Sardegna  Paesaggio e patrimonio culturale
#         Sardegna  Paesaggio e patrimonio culturale
#         Sardegna  Paesaggio e patrimonio culturale
#         Sardegna  Paesaggio e patrimonio culturale
#
#                                                   Territorio Dominio  \
# Annuale Piemonte  Densità e rilevanza del patrimonio museale  Totale
#         Piemonte  Densità e rilevanza del patrimonio museale  Totale
#         Piemonte  Densità e rilevanza del patrimonio museale  Totale
#         Piemonte  Densità e rilevanza del patrimonio museale  Totale
# ...

# %%
df2 = df2.droplevel(0)

# %%
df2.head()
# Out:
#                                  Frequenza  \
# Piemonte  Paesaggio e patrimonio culturale
# Piemonte  Paesaggio e patrimonio culturale
# Piemonte  Paesaggio e patrimonio culturale
# Piemonte  Paesaggio e patrimonio culturale
# Piemonte  Paesaggio e patrimonio culturale
#
#                                           Territorio Dominio  Indicatore  \
# Piemonte  Densità e rilevanza del patrimonio museale  Totale        2025
# Piemonte  Densità e rilevanza del patrimonio museale  Totale        2025
# Piemonte  Densità e rilevanza del patrimonio museale  Totale        2025
# Piemonte  Densità e rilevanza del patrimonio museale  Totale        2025
# Piemonte  Densità e rilevanza del patrimonio museale  Totale        2025
#
#           Sesso  Edizione  TIME_PERIOD  Osservazione  \
# Piemonte   2015      1.19          NaN           NaN
# Piemonte   2018      1.17          NaN           NaN
# Piemonte   2019      1.08          NaN           NaN
# ...

# %%
#df2 = df.loc[:,["Sesso", "Edizione"]]
#df.columns = ["Territorio", "Anno", "Osservazioni"]
df2.columns
# Out:
# Index(['Frequenza', 'Territorio', 'Dominio', 'Indicatore', 'Sesso', 'Edizione',
#        'TIME_PERIOD', 'Osservazione', ''Stato dell"'osservazione'',
#        'Territorio (NOTE_REF_AREA)', 'Codifica territoriale ufficiale Istat',
#        'Indicatore (NOTE_DATA_TYPE)', 'Descrizione indicatore', 'Fonte',
#        'Tempo (NOTE_TIME_PERIOD)', 'Anno base', 'Unità di misura',
#        'Unità di moltiplicazione'],
#       dtype='object')
